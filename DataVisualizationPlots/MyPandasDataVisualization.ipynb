# %%
import numpy as np
import pandas as pd
import seaborn as sb

# %%
# %matplotlib inline

# %%
df1=pd.read_csv('df1',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist')

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()

# %%
# transparency 
df2.plot.area(alpha=0.4)

# %%
# Bar plot 
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
sb.barplot(data=df2,x='a',y='b')

# %%
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C') # column c as color

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm') # column c as color

# %%
df1.plot.scatter(x='A',y='B',s=df1['C'])#using size instead of colour
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\collections.py:877: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)#this is to get concentrated
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\collections.py:877: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
# box plot 
df2.plot.box()

# %%
# random nos of 1000 rows with 2 columns in each row
randomnos =np.random.randn(1000,2)
randomnos
# Out:
# array([[-0.14075976, -0.57032377],
#        [ 0.45457751, -0.87090144],
#        [-1.36457961,  1.47409318],
#        ...,
#        [-1.11011898, -0.49245964],
#        [ 0.62632723, -0.87883944],
#        [-0.34929627, -0.51787819]])

# %%
 # keep the cols as a and b
df=pd.DataFrame(randomnos,columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0 -0.140760 -0.570324
# 1  0.454578 -0.870901
# 2 -1.364580  1.474093
# 3  1.710632  0.449936
# 4 -0.987104  0.975942

# %%
# hexgonal plot
df.plot.hexbin(x='a',y='b')

# %%
# hex plot with size
df.plot.hexbin(x='a',y='b',gridsize=25)

# %%
df2['a'].plot.density()
